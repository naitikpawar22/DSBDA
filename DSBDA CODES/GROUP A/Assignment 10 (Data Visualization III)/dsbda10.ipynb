# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Iris = pd.read_csv("C:/Users/prajw/Desktop/Indexs/DSBDA print/GROUP A/Assignment 10 (Data Visualization III)/Iris.csv")
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.shape
# Out:
# (150, 6)

# %%
Iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
Iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(Iris.groupby('Species').size())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
print("\nThe features in the dataset are as follows:")

print("1. Sepal length : ", Iris['SepalLengthCm'].dtype)
print("2. Sepal width  : ", Iris['SepalWidthCm'].dtype)
print("3. Petal length : ", Iris['PetalLengthCm'].dtype)
print("4. Petal width  : ", Iris['PetalWidthCm'].dtype)
print("5. Species      : ", Iris['Species'].dtype)
# Out:
# The features in the dataset are as follows:
# 1. Sepal length :  float64
# 2. Sepal width  :  float64
# 3. Petal length :  float64
# 4. Petal width  :  float64
# 5. Species      :  object

# %%
print(Iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(x = Iris['SepalLengthCm'], kde=True)
plt.title('Distribution of Sepal Length')
plt.show()

# %%
sns.histplot(x = Iris['SepalWidthCm'], kde=True)
plt.title('Distribution of Sepal Width')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(x = Iris['PetalLengthCm'], kde=True)
plt.title('Distribution of Petal Length')
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# %%
import matplotlib.pyplot as plt

iris_df.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(x = Iris['PetalWidthCm'], kde=True)
plt.title('Distribution of Petal Width')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplots for each feature separately
sns.boxplot(x = Iris['SepalLengthCm'])
plt.title('Boxplot of Sepal Length')
plt.show()

sns.boxplot(x = Iris['SepalWidthCm'])
plt.title('Boxplot of Sepal Width')
plt.show()

sns.boxplot(x = Iris['PetalLengthCm'])
plt.title('Boxplot of Petal Length')
plt.show()

sns.boxplot(x = Iris['PetalWidthCm'])
plt.title('Boxplot of Petal Width')
plt.show()

# Boxplot comparing feature vs species
sns.boxplot(x = 'Species', y = 'SepalLengthCm', data = Iris)
plt.title('Sepal Length vs Species')
plt.show()

sns.boxplot(x = 'Species', y = 'PetalLengthCm', data = Iris)
plt.title('Petal Length vs Species')
plt.show()

# %%
sns.boxplot(data=Iris, orient="h")
plt.show()

# %%
sns.boxplot(x = 'sepal width (cm)', data = iris_df)
# Out:
# <Axes: xlabel='sepal width (cm)'>

# %%
Q1 = Iris.SepalWidthCm.quantile(0.25)
Q3 = Iris.SepalWidthCm.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# 0.5

# %%
data = Iris[Iris.SepalWidthCm < (Q1 - 1.5 * IQR) / (Iris.SepalWidthCm > (Q3 + 1.5 * IQR))]

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
